# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

URL = "https://www.4icu.org/top-universities-africa/"
page = requests.get(URL)
#print(page.content)

soup = bs(page.content,"lxml")
results = soup.find("div",class_1 = "th")
#results_1 = soup.find("div",class_1 = "container")
#results_1 = results.find_all("th")
#resuls_table = pd.DataFrame(results)

#print(results_2)
#list_1 = []
#print(results)
#result_elements = results.find_all("tr")

#final_result = results_elements.find_all("a href=")
#df = DataFrame(result_elements,["Rank","Univeristy","Country"])
#print(df)
print(results_elements)

#for result_element in results:
#    university_rank = result_element.find("td","b")
#    university_name = result_element.find("td","a href=")
#    university_country = result_element.find("td","fl flag")
    
#print(university_rank)
#print(university_name)
#print(university_country)
# Out:
# [<tr>
# <td><b>1</b></td>
# <td><a href="/reviews/4228.htm">University of Cape Town</a></td>
# <td><img alt="South Africa" class="fl flag-za" src="/i/bg.gif"> za</img></td>
# </tr>, <tr>
# <td><b>2</b></td>
# <td><a href="/reviews/4234.htm">University of Pretoria</a></td>
# <td><img alt="South Africa" class="fl flag-za" src="/i/bg.gif"/> za</td>
# </tr>, <tr>
# <td><b>3</b></td>
# <td><a href="/reviews/4239.htm">University of the Witwatersrand</a></td>
# <td><img alt="South Africa" class="fl flag-za" src="/i/bg.gif"/> za</td>
# </tr>, <tr>
# <td><b>4</b></td>
# <td><a href="/reviews/4236.htm">Universiteit Stellenbosch</a></td>
# <td><img alt="South Africa" class="fl flag-za" src="/i/bg.gif"/> za</td>
# </tr>, <tr>
# <td><b>5</b></td>
# <td><a href="/reviews/4225.htm">University of Johannesburg</a></td>
# <td><img alt="South Africa" class="fl flag-za" src="/i/bg.gif"/> za</td>
# </tr>, <tr>
# <td><b>6</b></td>
# <td><a href="/reviews/7671.htm">North-West University</a></td>
# ...
